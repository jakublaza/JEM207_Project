# %%
#Installing our package which contains fuctions, class, datasets and documentation. 

pip install -i https://test.pypi.org/simple/ IES-Project-Covid==1
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting IES-Project-Covid==1
#   Downloading https://test-files.pythonhosted.org/packages/fb/11/7975269d925d5d6c85df018aaff0ed6b7019062e1574349a7ecd871683e3/IES_Project_Covid-1-py3-none-any.whl (99.2 MB)
#      |████████████████████████████████| 99.2 MB 12.2 MB/s eta 0:00:01   |██▏                             | 6.7 MB 7.8 MB/s eta 0:00:12
# Installing collected packages: IES-Project-Covid
# Successfully installed IES-Project-Covid-1
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing module downloader

from app import downloader as d
from token1 import token

# %%
#Initializing class Covid_Data

covid = d.Covid_Data()
# Out:
# Class initialize, if you want to load data provided by this package - use method load_data()
#                  or you can download it on your own using method download(*args, *kwargs)
#  You can access documentation at: /Users/Jakub/opt/anaconda3/lib/python3.8/site-packages/app/docs/_build/html/index.html
# No data loaded or downloaded.

# %%
#Loading dataset that is part of the package

covid.load_data()
# Out:
# Data loaded

# %%
#Obataining information about the loaded dataset

covid.get_info()
covid.info
# Out:
# {'total cases': 2475609, 'start_date': '01.03.2020', 'end_date': '24.12.2021'}

# %%
#Checking how many pages were downloaded

covid.get_page(token)
# Out:
# You downloaded 496 pages out of total 490 pages.

# %%
#Loading module scraper

from app import scraper

# %%
district_pop = scraper.get_district_pop()

# %%
district_pop
# Out:
#                     Total      Men    Women
# Česká republika  10694480  5270358  5424122
# Praha             1337074   654927   682147
# Střední Čechy     1400879   693318   707561
# Jihozápad         1233364   610843   622521
# Severozápad       1107303   548415   558888
# ...                   ...      ...      ...
# Frýdek-Místek      214517   105684   108833
# Karviná            241919   117970   123949
# Nový Jičín         151330    74656    76674
# Opava              175570    85933    89637
# Ostrava-město      316466   153653   162813
#
# [99 rows x 3 columns]

# %%
import pandas as pd
import geopandas

# %%
#Loading map files to create a map graph
link_dist = "/Users/Jakub/opt/anaconda3/lib/python3.8/site-packages/app/data/map/PolbndDistDA.shp"
districts = geopandas.read_file(link_dist)

link_reg = "/Users/Jakub/opt/anaconda3/lib/python3.8/site-packages/app/data/map/PolbndRegDA.shp"
regions = geopandas.read_file(link_reg)

prague = regions.iloc[5]

# %%
#We performe some adjustments so the merge with covid data is smooth. We will be merging on column "district_code" 

prague = prague.drop(labels = ["REG_LABEL", "ANND"]).rename({"SHN1":"okres_lau_kod"})

districts = districts.rename(columns = {"SHN2":"okres_lau_kod"})


districts = districts.append(prague).drop(columns = ["DESN", "ISN", "F_CODE", "FCSUBTYPE"]).set_index("NAMN")

for i in range(78):
    districts["okres_lau_kod"][i] = districts["okres_lau_kod"][i][:6]
    
map_dataset = districts.merge(district_pop, left_on = "NAMN", right_index = True, how = "left")
# Out:
# <ipython-input-54-77ce30a096a3>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   districts["okres_lau_kod"][i] = districts["okres_lau_kod"][i][:6]

# %%
covid.data
# Out:
#                                                        @id  @type  \
# index
# 0        /api/v3/osoby/4f60d800-06d1-4d6e-98f8-168d1667...  osoby
# 250230   /api/v3/osoby/6d05f773-0dad-46ee-994c-14ba48ee...  osoby
# 250229   /api/v3/osoby/89502842-984f-4f2d-89a2-ffbb9c65...  osoby
# 250228   /api/v3/osoby/83417c3c-b53a-474f-9a21-1e1d3f1a...  osoby
# 1        /api/v3/osoby/ace62e87-5ffa-47be-99a8-ed5d95d8...  osoby
# ...                                                    ...    ...
# 2474226  /api/v3/osoby/ade77ce2-e200-4857-b4f6-c331479c...  osoby
# 2474225  /api/v3/osoby/50a161a6-f322-40e8-a2ae-3f9dfee0...  osoby
# 2474224  /api/v3/osoby/9aca9291-2855-47d0-96d2-6ca80c6a...  osoby
# 2474190  /api/v3/osoby/db45ebc9-574f-4d13-a5ef-92078298...  osoby
# 2475608  /api/v3/osoby/c4a3bc24-9a0f-40dd-a78a-b441be99...  osoby
#
#                                            id      datum   vek pohlavi  \
# index
# 0        4f60d800-06d1-4d6e-98f8-168d166782a9 2020-03-01  67.0       M
# 250230   6d05f773-0dad-46ee-994c-14ba48ee1166 2020-03-01  43.0       M
# 250229   89502842-984f-4f2d-89a2-ffbb9c65e2e5 2020-03-01  21.0       Z
# 250228   83417c3c-b53a-474f-9a21-1e1d3f1a7b1e 2020-03-01  67.0       M
# 1        ace62e87-5ffa-47be-99a8-ed5d95d89cca 2020-03-01  21.0       Z
# ...                                       ...        ...   ...     ...
# 2474226  ade77ce2-e200-4857-b4f6-c331479c30b7 2021-12-24  55.0       Z
# 2474225  50a161a6-f322-40e8-a2ae-3f9dfee0ee27 2021-12-24  13.0       Z
# 2474224  9aca9291-2855-47d0-96d2-6ca80c6a2690 2021-12-24  12.0       Z
# 2474190  db45ebc9-574f-4d13-a5ef-92078298da08 2021-12-24  37.0       M
# 2475608  c4a3bc24-9a0f-40dd-a78a-b441be990308 2021-12-24  24.0       M
#
#         kraj_nuts_kod okres_lau_kod  nakaza_v_zahranici nakaza_zeme_csu_kod  \
# index
# 0               CZ010        CZ0100                True                  IT
# 250230          CZ042        CZ0421                True                  IT
# 250229          CZ010        CZ0100                True                  IT
# 250228          CZ010        CZ0100                True                  IT
# 1               CZ010        CZ0100                True                  IT
# ...               ...           ...                 ...                 ...
# 2474226         CZ020        CZ020B               False                None
# 2474225         CZ020        CZ0201               False                None
# 2474224         CZ020        CZ020B               False                None
# 2474190         CZ020        CZ0209               False                None
# 2475608         CZ072        CZ0723               False                None
#
#          reportovano_khs
# index
# 0                   True
# 250230              True
# 250229              True
# 250228              True
# 1                   True
# ...                  ...
# 2474226             True
# 2474225             True
# 2474224             True
# 2474190             True
# 2475608             True
#
# [2475609 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

# %%
def plot_district_infec(day, table = False, show = "Total"):
    """
    Plots infections in Czech Republic districts 
    
    Parameters
    --------
    
    day (str): Specifies day for which it will be shown, in format YYYY-MM-DD
    
    table (boolean): Print table of districts, default is set to False
    
    show (str): 4 possible value: "Total" - shows total infections in district, "Rel" - shows infections per 1000 people
    in the district, "W/M" - shows ratio of men and women infecitons in districts
    
    Return
    -------
    plot and table (optional)
    """
    period = covid.data[covid.data["datum"] == day]
    infections = period.groupby(["okres_lau_kod"]).count()
    table_dist_infec = infections.reset_index()[["okres_lau_kod", "id"]]
    plot_data = map_dataset.merge(table_dist_infec, on = "okres_lau_kod", how = "outer").reset_index()
    plot_data['id'] = plot_data['id'].fillna(0)
    fig, ax = plt.subplots(1, 1)
    plot_data.plot("id", ax=ax, legend=True).set_axis_off()
    
    if show == "rel":
        plot_data["id"] = plot_data["id"]/plot_data["total"] * 1000
        fig, ax = plt.subplots(1, 1)
        plot_data.plot("id", ax=ax, legend=True).set_axis_off()
    
    if show == "W/M":
        period_men = period[period["pohlavi"] == "M"]
        period_women = period[period["pohlavi"] == "W"]
        infections_men = period_men.groupby(["okres_lau_kod"]).count().reset_index()[["okres_lau_kod", "id"]]
        infections_women = period_women.groupby(["okres_lau_kod"]).count().reset_index()[["okres_lau_kod", "id"]]
        table_dist_infec = infections_men.merge(infections_women, on = "okres_lau_kod", how = "outer")
        plot_data = map_dataset.merge(table_dist_infec, on = "okres_lau_kod", how = "outer").reset_index()
        plot_data['id_x'] = plot_data['id_x'].fillna(0)
        plot_data['id_y'] = plot_data['id_y'].fillna(0)
        rel_w = plot_data["id_y"]/int(plot_data["Women"])
        rel_m = plot_data["id_x"]/int(plot_data["Men"])
        try:
            plot_data["id"] = rel_m/(rel_m+rel_w)
        except:
            plot_data["id"] = 0.5
            
        
        
    
    if table:
        table = plot_data.sort_values(by = ["id"], ascending=False)[["NAMA", "id"]].rename(columns = {"NAMA" : "District", "id" : "Number of infections"})
        print(table)

# %%
plot_data
# Out:
#     index okres_lau_kod                NAMA     SHAPE_Leng    SHAPE_Area  \
# 0       0        CZ0204               Kolin  278686.732806  7.436418e+08
# 1       1        CZ0722    Uherske Hradiste  198904.212148  9.907005e+08
# 2       2        CZ0643         Brno-venkov  452327.523854  1.498883e+09
# 3       3        CZ0713           Prostejov  257863.341262  7.772739e+08
# 4       4        CZ0427      Usti nad Labem  127178.079528  4.047448e+08
# ..    ...           ...                 ...            ...           ...
# 73     73        CZ0642          Brno-mesto  121698.259279  2.298733e+08
# 74     74        CZ0411                Cheb  322090.645974  1.045142e+09
# 75     75        CZ0425                Most  170599.438045  4.668675e+08
# 76     76        CZ0711             Jesenik  159746.811701  7.190832e+08
# 77     77        CZ0100  Hlavni mesto Praha  156838.616770  4.963217e+08
#
#                                              geometry    Total     Men  \
# 0   POLYGON ((-716183.221 -1043636.904, -716234.62...   104246   51941
# 1   POLYGON ((-540628.601 -1167299.705, -540567.07...   141525   69526
# 2   POLYGON ((-594489.208 -1151114.831, -594133.83...   226878  112318
# 3   POLYGON ((-574071.439 -1109809.088, -574019.44...   108385   52936
# 4   POLYGON ((-760957.587 -958837.890, -760960.835...   118370   57983
# ..                                                ...      ...     ...
# 73  POLYGON ((-597609.424 -1149878.175, -597644.67...   382036  185900
# 74  POLYGON ((-901982.614 -992374.086, -901857.391...    90985   44891
# 75  POLYGON ((-793042.749 -965560.726, -792940.524...   110563   54914
# 76  POLYGON ((-561932.581 -1024356.763, -561889.06...    37585   18621
# 77  POLYGON ((-733582.756 -1034199.856, -733690.30...  1337074  654927
#
#      Women  id_x  id_y
# 0    52305   0.0   0.0
# 1    71999   0.0   0.0
# 2   114560   0.0   2.0
# 3    55449   0.0   0.0
# 4    60387   0.0   0.0
# ..     ...   ...   ...
# 73  196136   4.0   2.0
# 74   46094   0.0   0.0
# 75   55649   0.0   0.0
# 76   18964   0.0   0.0
# 77  682147  10.0  16.0
#
# [78 rows x 11 columns]

# %%
plot_district_infec("2020-06-01", table = True, show)
# Out:
#               District  Number of infections
# 77  Hlavni mesto Praha                  26.0
# 66             Karvina                  12.0
# 33             Olomouc                   8.0
# 73          Brno-mesto                   6.0
# 60      Hradec Kralove                   4.0
# ..                 ...                   ...
# 27            Rokycany                   0.0
# 26  Jablonec nad Nisou                   0.0
# 25           Plzen-jih                   0.0
# 24          Strakonice                   0.0
# 39            Chomutov                   0.0
#
# [78 rows x 2 columns]

# %%
period = covid.data[covid.data["datum"] == "2020-06-01"]
infections = period.groupby(["okres_lau_kod"]).count()
table_dist_infec = infections.reset_index()[["okres_lau_kod", "id"]]
period_men = period[period["pohlavi"] == "M"]
infections_men = period_men.groupby(["okres_lau_kod"]).count()
period_women = period[period["pohlavi"] == "Z"]
infections_women = period_women.groupby(["okres_lau_kod"]).count()
infections_men = period_men.groupby(["okres_lau_kod"]).count().reset_index()[["okres_lau_kod", "id"]]
infections_women = period_women.groupby(["okres_lau_kod"]).count().reset_index()[["okres_lau_kod", "id"]]
table_dist_infec = infections_men.merge(infections_women, on = "okres_lau_kod", how = "outer")
plot_data = map_dataset.merge(table_dist_infec, on = "okres_lau_kod", how = "outer").reset_index()
plot_data['id_x'] = plot_data['id_x'].fillna(0)
plot_data['id_y'] = plot_data['id_y'].fillna(0)

# %%
plot_data
# Out:
#     index okres_lau_kod                NAMA     SHAPE_Leng    SHAPE_Area  \
# 0       0        CZ0204               Kolin  278686.732806  7.436418e+08
# 1       1        CZ0722    Uherske Hradiste  198904.212148  9.907005e+08
# 2       2        CZ0643         Brno-venkov  452327.523854  1.498883e+09
# 3       3        CZ0713           Prostejov  257863.341262  7.772739e+08
# 4       4        CZ0427      Usti nad Labem  127178.079528  4.047448e+08
# ..    ...           ...                 ...            ...           ...
# 73     73        CZ0642          Brno-mesto  121698.259279  2.298733e+08
# 74     74        CZ0411                Cheb  322090.645974  1.045142e+09
# 75     75        CZ0425                Most  170599.438045  4.668675e+08
# 76     76        CZ0711             Jesenik  159746.811701  7.190832e+08
# 77     77        CZ0100  Hlavni mesto Praha  156838.616770  4.963217e+08
#
#                                              geometry    Total     Men  \
# 0   POLYGON ((-716183.221 -1043636.904, -716234.62...   104246   51941
# 1   POLYGON ((-540628.601 -1167299.705, -540567.07...   141525   69526
# 2   POLYGON ((-594489.208 -1151114.831, -594133.83...   226878  112318
# 3   POLYGON ((-574071.439 -1109809.088, -574019.44...   108385   52936
# 4   POLYGON ((-760957.587 -958837.890, -760960.835...   118370   57983
# ..                                                ...      ...     ...
# 73  POLYGON ((-597609.424 -1149878.175, -597644.67...   382036  185900
# 74  POLYGON ((-901982.614 -992374.086, -901857.391...    90985   44891
# 75  POLYGON ((-793042.749 -965560.726, -792940.524...   110563   54914
# 76  POLYGON ((-561932.581 -1024356.763, -561889.06...    37585   18621
# 77  POLYGON ((-733582.756 -1034199.856, -733690.30...  1337074  654927
#
#      Women  id_x  id_y
# 0    52305   0.0   0.0
# 1    71999   0.0   0.0
# 2   114560   0.0   2.0
# 3    55449   0.0   0.0
# 4    60387   0.0   0.0
# ..     ...   ...   ...
# 73  196136   4.0   2.0
# 74   46094   0.0   0.0
# 75   55649   0.0   0.0
# 76   18964   0.0   0.0
# 77  682147  10.0  16.0
#
# [78 rows x 11 columns]

# %%
rel_w = plot_data["id_y"]/int(plot_data["Women"].values)
rel_m = plot_data["id_x"]/int(plot_data["Men"].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-4590043b75bb> in <module>
# ----> 1 rel_w = plot_data["id_y"]/int(plot_data["Women"].values)
#       2 rel_m = plot_data["id_x"]/int(plot_data["Men"].values)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
plot_data["Women"].values
# Out:
# array(['52305', '71999', '114560', '55449', '60387', '89637', '50418',
#        '43718', '57941', '26915', '25321', '39744', '59943', '59943',
#        '40352', '36208', '78087', '51871', '57003', '36383', '48899',
#        '99366', '47562', '64397', '35592', '34628', '46642', '24702',
#        '53556', '64783', '77654', '52068', '55326', '120733', '69274',
#        '36238', '100365', '55542', '43610', '62261', '55456', '65326',
#        '52514', '38390', '58046', '88302', '108833', '89253', '45716',
#        '60862', '40234', '72064', '30345', '59198', '55349', '85057',
#        '64537', '52579', '76674', '45848', '83982', '96063', '97697',
#        '162813', '58477', '59239', '123949', '46880', '27724', '28011',
#        '43416', '59084', '51775', '196136', '46094', '55649', '18964',
#        '682147'], dtype=object)

# %%
w = 2.0/196136

# %%
m = plot_data.iloc[73].id_x/int(plot_data.iloc[73].Men)

# %%
m/(w+m)
# Out:
# 0.678469382813419

# %%
4/6
# Out:
# 0.6666666666666666

# %%
plot_data = map_dataset.merge(table_dist_infec, on = "okres_lau_kod", how = "outer").reset_index()
plot_data['id'] = plot_data['id'].fillna(0)

# %%
plot_data.sort_values(by = ["id"], ascending=False)[["NAMA", "id"]]
# Out:
#                   NAMA    id
# 77  Hlavni mesto Praha  26.0
# 66             Karvina  12.0
# 33             Olomouc   8.0
# 73          Brno-mesto   6.0
# 60      Hradec Kralove   4.0
# ..                 ...   ...
# 27            Rokycany   0.0
# 26  Jablonec nad Nisou   0.0
# 25           Plzen-jih   0.0
# 24          Strakonice   0.0
# 39            Chomutov   0.0
#
# [78 rows x 2 columns]

# %%
day = covid.data[covid.data["datum"] == "2020-03-01"]

# %%
b = day.groupby(["okres_lau_kod"]).count()

# %%
b
# Out:
#                @id  @type  id  datum  vek  pohlavi  kraj_nuts_kod  \
# okres_lau_kod
# CZ0100           4      4   4      4    4        4              4
# CZ0421           2      2   2      2    2        2              2
#
#                nakaza_v_zahranici  nakaza_zeme_csu_kod  reportovano_khs
# okres_lau_kod
# CZ0100                          4                    4                4
# CZ0421                          2                    2                2

# %%
b = b.reset_index()[["okres_lau_kod", "id"]]
b
# Out:
#   okres_lau_kod  id
# 0        CZ0100   4
# 1        CZ0421   2

# %%
districts = districts.rename(columns = {"district_code":"okres_lau_kod"})
okresy = districts.merge(b, on = "okres_lau_kod", how = "outer")

# %%
okresy = okresy.reset_index()
okresy['id'] = okresy['id'].fillna(0)
okresy
# Out:
#     index okres_lau_kod     SHAPE_Leng    SHAPE_Area  \
# 0       0        CZ0204  278686.732806  7.436418e+08
# 1       1        CZ0722  198904.212148  9.907005e+08
# 2       2        CZ0643  452327.523854  1.498883e+09
# 3       3        CZ0713  257863.341262  7.772739e+08
# 4       4        CZ0427  127178.079528  4.047448e+08
# ..    ...           ...            ...           ...
# 73     73        CZ0642  121698.259279  2.298733e+08
# 74     74        CZ0411  322090.645974  1.045142e+09
# 75     75        CZ0425  170599.438045  4.668675e+08
# 76     76        CZ0711  159746.811701  7.190832e+08
# 77     77        CZ0100  156838.616770  4.963217e+08
#
#                                              geometry   id
# 0   POLYGON ((-716183.221 -1043636.904, -716234.62...  0.0
# 1   POLYGON ((-540628.601 -1167299.705, -540567.07...  0.0
# 2   POLYGON ((-594489.208 -1151114.831, -594133.83...  0.0
# 3   POLYGON ((-574071.439 -1109809.088, -574019.44...  0.0
# 4   POLYGON ((-760957.587 -958837.890, -760960.835...  0.0
# ..                                                ...  ...
# 73  POLYGON ((-597609.424 -1149878.175, -597644.67...  0.0
# 74  POLYGON ((-901982.614 -992374.086, -901857.391...  0.0
# 75  POLYGON ((-793042.749 -965560.726, -792940.524...  0.0
# 76  POLYGON ((-561932.581 -1024356.763, -561889.06...  0.0
# 77  POLYGON ((-733582.756 -1034199.856, -733690.30...  4.0
#
# [78 rows x 6 columns]
